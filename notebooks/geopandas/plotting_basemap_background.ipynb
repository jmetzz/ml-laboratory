# %%
# %matplotlib inline

# %% [markdown]
# Adding a background map to plots
# --------------------------------
#
# This example shows how you can add a background basemap to plots created
# with the geopandas ``.plot()`` method. This makes use of the
# `contextily <https://github.com/darribas/contextily>`__ package to retrieve
# web map tiles from several sources (OpenStreetMap, Stamen).

# %%
import sys

# !conda install --yes --prefix {sys.prefix} -c conda-forge geopandas descartes contextily

# sphinx_gallery_thumbnail_number = 3
import geopandas
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/jean.metz/miniconda/envs/ml-laboratory
#
#   added / updated specs:
#     - contextily
#     - descartes
#     - geopandas
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     affine-2.3.0               |             py_0          16 KB  conda-forge
#     contextily-1.0.0           |             py_0          24 KB  conda-forge
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     geopy-1.21.0               |             py_0          58 KB  conda-forge
#     mercantile-1.1.3           |     pyh9f0ad1d_0          15 KB  conda-forge
#     rasterio-1.0.28            |   py37h238e834_1         8.0 MB  conda-forge
#     snuggs-1.4.7               |             py_0           8 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         8.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   affine             conda-forge/noarch::affine-2.3.0-py_0
#   contextily         conda-forge/noarch::contextily-1.0.0-py_0
#   geographiclib      conda-forge/noarch::geographiclib-1.50-py_0
#   geopy              conda-forge/noarch::geopy-1.21.0-py_0
#   mercantile         conda-forge/noarch::mercantile-1.1.3-pyh9f0ad1d_0
#   rasterio           conda-forge/osx-64::rasterio-1.0.28-py37h238e834_1
#   snuggs             conda-forge/noarch::snuggs-1.4.7-py_0
#
#
#
# Downloading and Extracting Packages
# geographiclib-1.50   | 34 KB     | ##################################### | 100%
# geopy-1.21.0         | 58 KB     | ##################################### | 100%
# rasterio-1.0.28      | 8.0 MB    | ##################################### | 100%
# snuggs-1.4.7         | 8 KB      | ##################################### | 100%
# affine-2.3.0         | 16 KB     | ##################################### | 100%
# mercantile-1.1.3     | 15 KB     | ##################################### | 100%
# contextily-1.0.0     | 24 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %% [markdown]
# Let's use the NYC borough boundary data that is available in geopandas
# datasets. Plotting this gives the following result:

# %%
df = geopandas.read_file(geopandas.datasets.get_path("nybb"))
ax = df.plot(figsize=(10, 10), alpha=0.5, edgecolor="k")

# %% [markdown]
# Convert the data to Web Mercator
# ================================
#
# Web map tiles are typically provided in
# `Web Mercator <https://en.wikipedia.org/wiki/Web_Mercator>`__
# (`EPSG 3857 <https://epsg.io/3857>`__), so we need to make sure to convert
# our data first to the same CRS to combine our polygons and background tiles
# in the same map:

# %%
df = df.to_crs(epsg=3857)

# %%
import contextily as ctx

# %% [markdown]
# Add background tiles to plot
# ============================
#
# We can use `add_basemap` function of contextily to easily add a background
# map to our plot. :

# %%
ax = df.plot(figsize=(10, 10), alpha=0.5, edgecolor="k")
ctx.add_basemap(ax)

# %% [markdown]
# We can control the detail of the map tiles using the optional `zoom` keyword
# (be careful to not specify a too high `zoom` level,
# as this can result in a large download).:

# %%
ax = df.plot(figsize=(10, 10), alpha=0.5, edgecolor="k")
ctx.add_basemap(ax, zoom=12)

# %% [markdown]
# By default, contextily uses the Stamen Terrain style. We can specify a
# different style using ``ctx.providers``:

# %%
ax = df.plot(figsize=(10, 10), alpha=0.5, edgecolor="k")
ctx.add_basemap(ax, url=ctx.providers.Stamen.TonerLite)
ax.set_axis_off()
# Out:
# /Users/jean.metz/miniconda/envs/ml-laboratory/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: The "url" option is deprecated. Please use the "source" argument instead.
